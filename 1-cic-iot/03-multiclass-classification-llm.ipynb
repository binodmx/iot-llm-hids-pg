# %% [markdown]
# # Load Dataset

# %%
################################################################################
# Load dataset and split it into training and test set (multi-class)
################################################################################

import pandas as pd
import os
from tabulate import tabulate

dataset_name = "cic-iot"
sample_size = 100000

# Load dataset
df        = pd.read_csv(os.getcwd() + '/data/sample-multiclass.csv',  low_memory=False)
train_df  = pd.read_csv(os.getcwd() + '/data/train-multiclass.csv',   low_memory=False)
test_df   = pd.read_csv(os.getcwd() + '/data/test-multiclass.csv',    low_memory=False)

# Keep original multi-class labels — NO binary merging

train_dfs, test_dfs = {}, {}
for label, group in df.groupby('label'):
    train_part = group.sample(frac=0.8, random_state=42)
    test_part  = group.drop(train_part.index)
    train_dfs[label] = train_part
    test_dfs[label]  = test_part

df_train = pd.concat(train_dfs.values())
df_test  = pd.concat(test_dfs.values())

X_train = train_df.drop(columns=['label'])
y_train = train_df['label']
X_test  = test_df.drop(columns=['label'])
y_test  = test_df['label']

# Table: class | total | train | test
table_data = [[lbl, len(group), len(train_dfs[lbl]), len(test_dfs[lbl])]
              for lbl, group in df.groupby('label')]
print(tabulate(table_data, headers=["Class", "Total", "Train", "Test"], tablefmt="grid"))
# Out:
# +--------------------+---------+---------+--------+
# | Class              |   Total |   Train |   Test |
# +====================+=========+=========+========+
# | BenignTraffic      |    2348 |    1878 |    470 |
# +--------------------+---------+---------+--------+
# | DDoS-Flood         |    2348 |    1878 |    470 |
# +--------------------+---------+---------+--------+
# | DDoS-Fragmentation |    2163 |    1730 |    433 |
# +--------------------+---------+---------+--------+
# | DNS_Spoofing       |     405 |     324 |     81 |
# +--------------------+---------+---------+--------+
# | DoS-Flood          |    2348 |    1878 |    470 |
# +--------------------+---------+---------+--------+
# | MITM-ArpSpoofing   |     653 |     522 |    131 |
# +--------------------+---------+---------+--------+
# | Mirai              |    2348 |    1878 |    470 |
# +--------------------+---------+---------+--------+
# | Recon              |     705 |     564 |    141 |
# +--------------------+---------+---------+--------+

# %% [markdown]
# # ML Baseline (Multi-Class)

# %%
################################################################################
# Decision Tree and Random Forest (multi-class)
################################################################################

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
import os
import time

os.makedirs("results/ml", exist_ok=True)

for Model, fname in [(DecisionTreeClassifier, "result-dt-multiclass-100000.txt"),
                     (RandomForestClassifier,  "result-rf-multiclass-100000.txt")]:
    model = Model(random_state=42)
    model.fit(X_train, y_train)
    start = time.time()
    y_pred = model.predict(X_test)
    elapsed = time.time() - start
    report = classification_report(y_true=y_test, y_pred=y_pred, digits=4)
    matrix = confusion_matrix(y_test, y_pred)
    print(f"=== {Model.__name__} ({elapsed:.4f}s) ===")
    print(report)
    with open(f"results/ml/{fname}", "w") as f:
        f.write(f"Classification Report\n{report}\n\nConfusion Matrix\n{matrix}\n")
# Out:
# === DecisionTreeClassifier (0.0007s) ===
#                     precision    recall  f1-score   support
#
#      BenignTraffic     0.9163    0.8851    0.9004       470
#         DDoS-Flood     0.9979    0.9936    0.9957       470
# DDoS-Fragmentation     0.9954    0.9954    0.9954       433
#       DNS_Spoofing     0.6744    0.7160    0.6946        81
#          DoS-Flood     0.9979    1.0000    0.9989       470
#   MITM-ArpSpoofing     0.6889    0.7099    0.6992       131
#              Mirai     0.9957    0.9936    0.9947       470
#              Recon     0.7467    0.7943    0.7698       141
#
#           accuracy                         0.9430      2666
#          macro avg     0.8766    0.8860    0.8811      2666
#       weighted avg     0.9444    0.9430    0.9436      2666
#
# === RandomForestClassifier (0.0114s) ===
#                     precision    recall  f1-score   support
#
#      BenignTraffic     0.8577    0.9617    0.9067       470
#         DDoS-Flood     1.0000    0.9957    0.9979       470
# DDoS-Fragmentation     0.9931    0.9977    0.9954       433
#       DNS_Spoofing     0.8367    0.5062    0.6308        81
#          DoS-Flood     0.9979    1.0000    0.9989       470
#   MITM-ArpSpoofing     0.8684    0.7557    0.8082       131
#              Mirai     1.0000    0.9957    0.9979       470
#              Recon     0.7836    0.7447    0.7636       141
#
#           accuracy                         0.9509      2666
#          macro avg     0.9172    0.8697    0.8874      2666
#       weighted avg     0.9505    0.9509    0.9487      2666

# %% [markdown]
# # Vector Store — Per-Class Representative Samples

# %%
################################################################################
# Build class_entries dict with representative samples per class
################################################################################

import json
import numpy as np
from langchain_huggingface.embeddings import HuggingFaceEmbeddings
from tqdm import tqdm

embeddings = HuggingFaceEmbeddings(
    model_name='BAAI/bge-m3',
    model_kwargs={'device': 'mps'},
    encode_kwargs={'normalize_embeddings': True, 'batch_size': 64}
)

feature_cols = X_train.columns.tolist()
n_results = 10
max_embed_per_class = 100   # cap to avoid slow startup

class_entries = {}
for label in tqdm(df['label'].unique(), desc="Building class entries"):
    class_df = train_dfs[label].drop(columns=['label'])
    sample_df = class_df.sample(n=min(max_embed_per_class, len(class_df)), random_state=42)
    docs = [str(row.tolist()) for _, row in sample_df.iterrows()]
    # Embed docs
    vecs = np.array(embeddings.embed_documents(docs))
    mean_vec = vecs.mean(axis=0)
    # Cosine similarities to mean
    norms = np.linalg.norm(vecs, axis=1) * np.linalg.norm(mean_vec)
    sims = (vecs @ mean_vec) / np.where(norms == 0, 1e-9, norms)
    top_idx = np.argsort(sims)[::-1][:n_results]
    top_rows = sample_df.iloc[top_idx]
    # Transpose to feature-keyed dict
    entries = {}
    for col in feature_cols:
        entries[col] = top_rows[col].tolist()
    class_entries[label] = entries

print("class_entries keys:", list(class_entries.keys()))
# Out:
# Building class entries: 100%|██████████| 8/8 [00:46<00:00,  5.75s/it]
# class_entries keys: ['DDoS-Flood', 'DoS-Flood', 'Mirai', 'BenignTraffic', 'DDoS-Fragmentation', 'Recon', 'MITM-ArpSpoofing', 'DNS_Spoofing']

# %% [markdown]
# # Tool Definition

# %%
################################################################################
# Tool: evaluate_rule (multi-class aware)
################################################################################

from sklearn.metrics import classification_report
from tqdm import tqdm
import operator
from typing import Annotated
from langchain_core.tools import tool

show_progress = False
operations = {'<': operator.lt, '>': operator.gt, '==': operator.eq,
              '<=': operator.le, '>=': operator.ge, '!=': operator.ne}

@tool
def evaluate_rule(
    feature_name: Annotated[str, "Feature name"],
    value:        Annotated[str, "Value"],
    op:           Annotated[str, "Operator"],
    target_class: Annotated[str, "Target class name"]
) -> float:
    """Evaluate rule on training set. Returns macro F1 for target_class vs all others."""
    try:
        value = float(value)
    except ValueError:
        pass
    if op not in operations:
        raise ValueError(f"Unsupported operator: {op}")
    y_true, y_pred = [], []
    for lbl, df_cls in train_dfs.items():
        df_feat = df_cls.drop(columns=['label'])
        for i in tqdm(range(len(df_feat)), disable=not show_progress,
                      desc=f"Eval {lbl[:12]}..."):
            y_true.append("target" if lbl == target_class else "other")
            y_pred.append("target" if operations[op](df_feat.iloc[i][feature_name], value) else "other")
    report = classification_report(y_true, y_pred, digits=4, output_dict=True, zero_division=0)
    return report['macro avg']['f1-score']

# %% [markdown]
# # Prompt Template

# %%
################################################################################
# Prompt Template
################################################################################

from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

system_message = ("system",
"""You are a network security analyst specialising in IoT intrusion detection.
You are given labelled network traffic data with named features and numeric values.
Your task is to generate exactly {k} deterministic threshold rules to identify '{target_class}' traffic.

Rules must:
- Use ONLY inequality operators: '>', '<', '>=', '<='
- NEVER use '==' or '!=' — these are forbidden for numeric features
- Reference only feature names present in the data
- Be range-based thresholds that generalise beyond the exact sample values shown
- You MUST make exactly {k} tool calls — one per rule, no more, no less.

Good rule example: Header_Length < 100
Bad rule example: Header_Length == 54.0  ← FORBIDDEN"""
)

human_message = ("user",
"""Analyze the following network data and generate rules for the top {k} important features \
to identify '{target_class}' entries.

Target Class Entries:
```{target_entries}```

Other Class Entries (sample):
```{other_entries}```"""
)

prompt = ChatPromptTemplate.from_messages([
    system_message,
    human_message,
    MessagesPlaceholder("msgs")
])

# %% [markdown]
# # LLM Setup

# %%
################################################################################
# LLM Setup and Tool Binding
################################################################################

import os
import dotenv
# from langchain_openai import ChatOpenAI
from langchain_anthropic import ChatAnthropic

dotenv.load_dotenv(os.getcwd() + '/../.env')

# model_name = "gpt-4o"
model_name = "claude-haiku-4-5-20251001"
# llm = ChatOpenAI(model=model_name, temperature=0.1)
llm = ChatAnthropic(model=model_name, temperature=0.1)

llm_with_tool = llm.bind_tools([evaluate_rule])

# %% [markdown]
# # Feedback Loop (Per Class)

# %%
################################################################################
# Per-class feedback loop — improved
# Persist learned rules to disk for downstream evaluation
################################################################################

import json
import os
from langchain_core.messages import HumanMessage

chain = prompt | llm_with_tool

CLASS_CONFIG = {
    'DDoS-Flood':        {'max_rounds': 15, 'k': 5},
    'DoS-Flood':         {'max_rounds': 12, 'k': 7},  # oscillating — more k helps
    'Mirai':             {'max_rounds': 15, 'k': 5},
    'DDoS-Fragmentation':{'max_rounds': 15, 'k': 5},
    'Recon':             {'max_rounds': 12, 'k': 7},  # hard class — more rules
    'MITM-ArpSpoofing':  {'max_rounds': 12, 'k': 7},
    'DNS_Spoofing':      {'max_rounds': 15, 'k': 7},  # weakest — needs both
}

# n_repetitions  = 8        # more rounds — DNS_Spoofing needed 4 just to recover
# k              = 5
patience       = 4        # early stop if no improvement for this many rounds
show_progress  = False
class_rules    = {}

os.makedirs("results/llm", exist_ok=True)
rules_output_path = "results/llm/class_rules-multiclass-100000.json"

non_benign_classes = [lbl for lbl in df['label'].unique() if lbl != 'BenignTraffic']

# Build other_entries: sample from ALL non-target classes (not just BenignTraffic)
# Cap at 3 rows per class to keep prompt size manageable
def build_other_entries(target_class, class_entries, rows_per_class=3):
    other = {}
    for cls, entries in class_entries.items():
        if cls != target_class:
            other[cls] = list(entries)[:rows_per_class]
    return other

for target_class in non_benign_classes:
    print(f"\n=== Target class: {target_class} ===")

    cfg        = CLASS_CONFIG[target_class]
    max_rounds = cfg['max_rounds']
    k          = cfg['k']

    n               = 0
    no_improve      = 0
    best_mean_f1    = 0.0
    best_tool_calls = []
    train_f1_scores = []
    msgs            = []

    target_entries = json.dumps(class_entries[target_class])
    other_entries  = json.dumps(build_other_entries(target_class, class_entries))

    while n < max_rounds and no_improve < patience:
        ai_msg = chain.invoke({
            "k": k, "target_class": target_class,
            "target_entries": target_entries,
            "other_entries": other_entries,
            "msgs": msgs
        })

        # Invoke tools and collect per-rule scores
        tool_msgs   = []
        rule_scores = []
        for tool_call in ai_msg.tool_calls:
            tool_msg = evaluate_rule.invoke(tool_call)
            tool_msgs.append(tool_msg)
            try:
                rule_scores.append(float(tool_msg.content))
            except (ValueError, TypeError):
                rule_scores.append(0.0)

        mean_f1 = sum(rule_scores) / len(rule_scores) if rule_scores else 0.0

        # Best-state preservation — only keep rules if this round improved
        if mean_f1 > best_mean_f1:
            best_mean_f1 = mean_f1
            best_tool_calls = list(ai_msg.tool_calls)
            no_improve = 0
        else:
            no_improve += 1

        # Per-rule score feedback — tell the model exactly which rules scored what
        rule_feedback_lines = []
        for i, (tc, score) in enumerate(zip(ai_msg.tool_calls, rule_scores)):
            args = tc["args"]
            rule_feedback_lines.append(
                f"  Rule {i+1}: {args['feature_name']} {args['op']} {args['value']} "
                f"-> F1={score:.4f} ({'KEEP' if score >= mean_f1 else 'REVISE'})"
            )
        rule_feedback = "\n".join(rule_feedback_lines)

        human_msg = HumanMessage(
            f"Round {n+1} results (best so far: {best_mean_f1:.4f}):\n"
            f"{rule_feedback}\n\n"
            f"Mean F1 this round: {mean_f1:.4f}. "
            f"Revise rules marked REVISE by trying different threshold values or a different feature. "
            f"Keep rules marked KEEP unchanged. "
            f"Generate exactly {k} rules for '{target_class}' and make exactly {k} tool calls."
        )

        msgs.extend([ai_msg, *tool_msgs, human_msg])
        train_f1_scores.append(mean_f1)
        n += 1

        usage_info = ai_msg.response_metadata.get("usage", {})
        token_usage = {
            "completion_tokens": usage_info.get("output_tokens", 0),
            "prompt_tokens": usage_info.get("input_tokens", 0),
            "total_tokens": usage_info.get("input_tokens", 0) + usage_info.get("output_tokens", 0)
        }
        print(f"  Round: {n}  Mean F1: {mean_f1:.4f}  Best: {best_mean_f1:.4f}  "
              f"No-improve: {no_improve}  Tokens: {token_usage}")
        
        # After collecting rule_scores, validate operators
        for tc in ai_msg.tool_calls:
            if tc["args"]["op"] in ["==", "!="]:
                print(f"  WARNING: equality operator detected in rule — {tc['args']}")

    # Use best rules, not last-round rules; store JSON-serializable structure
    class_rules[target_class] = [{"args": tc["args"]} for tc in best_tool_calls]
    print(f"  Train F1 history: {train_f1_scores}")
    print(f"  Final best F1: {best_mean_f1:.4f}  (stopped after {n} rounds)")


with open(rules_output_path, "w") as f:
    json.dump(class_rules, f, indent=2)

print("\nDone. Classes with rules:", list(class_rules.keys()))
print(f"Saved class rules to: {rules_output_path}")
# Out:
# === Target class: DDoS-Flood ===
#   Round: 1  Mean F1: 0.4269  Best: 0.4269  No-improve: 0  Tokens: {'completion_tokens': 710, 'prompt_tokens': 3371, 'total_tokens': 4081}
#   Round: 2  Mean F1: 0.5901  Best: 0.5901  No-improve: 0  Tokens: {'completion_tokens': 548, 'prompt_tokens': 4481, 'total_tokens': 5029}
#   Round: 3  Mean F1: 0.6197  Best: 0.6197  No-improve: 0  Tokens: {'completion_tokens': 553, 'prompt_tokens': 5429, 'total_tokens': 5982}
#   Round: 4  Mean F1: 0.5085  Best: 0.6197  No-improve: 1  Tokens: {'completion_tokens': 557, 'prompt_tokens': 6385, 'total_tokens': 6942}
#   Round: 5  Mean F1: 0.6808  Best: 0.6808  No-improve: 0  Tokens: {'completion_tokens': 555, 'prompt_tokens': 7347, 'total_tokens': 7902}
#   Round: 6  Mean F1: 0.6880  Best: 0.6880  No-improve: 0  Tokens: {'completion_tokens': 552, 'prompt_tokens': 8304, 'total_tokens': 8856}
#   Round: 7  Mean F1: 0.6909  Best: 0.6909  No-improve: 0  Tokens: {'completion_tokens': 547, 'prompt_tokens': 9258, 'total_tokens': 9805}
#   Round: 8  Mean F1: 0.7274  Best: 0.7274  No-improve: 0  Tokens: {'completion_tokens': 550, 'prompt_tokens': 10205, 'total_tokens': 10755}
#   Round: 9  Mean F1: 0.7009  Best: 0.7274  No-improve: 1  Tokens: {'completion_tokens': 549, 'prompt_tokens': 11157, 'total_tokens': 11706}
#   Round: 10  Mean F1: 0.7304  Best: 0.7304  No-improve: 0  Tokens: {'completion_tokens': 549, 'prompt_tokens': 12104, 'total_tokens': 12653}
#   Round: 11  Mean F1: 0.7316  Best: 0.7316  No-improve: 0  Tokens: {'completion_tokens': 550, 'prompt_tokens': 13050, 'total_tokens': 13600}
#   Round: 12  Mean F1: 0.7341  Best: 0.7341  No-improve: 0  Tokens: {'completion_tokens': 547, 'prompt_tokens': 13999, 'total_tokens': 14546}
#   Round: 13  Mean F1: 0.6277  Best: 0.7341  No-improve: 1  Tokens: {'completion_tokens': 548, 'prompt_tokens': 14944, 'total_tokens': 15492}
#   Round: 14  Mean F1: 0.7235  Best: 0.7341  No-improve: 2  Tokens: {'completion_tokens': 551, 'prompt_tokens': 15890, 'total_tokens': 16441}
#   Round: 15  Mean F1: 0.6265  Best: 0.7341  No-improve: 3  Tokens: {'completion_tokens': 551, 'prompt_tokens': 16841, 'total_tokens': 17392}
#   Train F1 history: [0.42686441380416706, 0.5901005167326283, 0.6196747685967197, 0.5084886231697986, 0.6808206038126533, 0.6880159682705111, 0.690911855789426, 0.7273949090445578, 0.7009239810427029, 0.7303990726832791, 0.731574160168319, 0.7340611811618852, 0.6277192619185643, 0.723489897332132, 0.6265467444973041]
#   Final best F1: 0.7341  (stopped after 15 rounds)
#
# === Target class: DoS-Flood ===
#   Round: 1  Mean F1: 0.3605  Best: 0.3605  No-improve: 0  Tokens: {'completion_tokens': 919, 'prompt_tokens': 3420, 'total_tokens': 4339}
#   Round: 2  Mean F1: 0.4777  Best: 0.4777  No-improve: 0  Tokens: {'completion_tokens': 735, 'prompt_tokens': 4864, 'total_tokens': 5599}
#   Round: 3  Mean F1: 0.4758  Best: 0.4777  No-improve: 1  Tokens: {'completion_tokens': 723, 'prompt_tokens': 6122, 'total_tokens': 6845}
#   Round: 4  Mean F1: 0.5416  Best: 0.5416  No-improve: 0  Tokens: {'completion_tokens': 730, 'prompt_tokens': 7367, 'total_tokens': 8097}
#   Round: 5  Mean F1: 0.5514  Best: 0.5514  No-improve: 0  Tokens: {'completion_tokens': 726, 'prompt_tokens': 8616, 'total_tokens': 9342}
#   Round: 6  Mean F1: 0.6593  Best: 0.6593  No-improve: 0  Tokens: {'completion_tokens': 723, 'prompt_tokens': 9864, 'total_tokens': 10587}
#   Round: 7  Mean F1: 0.6583  Best: 0.6593  No-improve: 1  Tokens: {'completion_tokens': 716, 'prompt_tokens': 11098, 'total_tokens': 11814}
#   Round: 8  Mean F1: 0.6624  Best: 0.6624  No-improve: 0  Tokens: {'completion_tokens': 715, 'prompt_tokens': 12323, 'total_tokens': 13038}
#   Round: 9  Mean F1: 0.6629  Best: 0.6629  No-improve: 0  Tokens: {'completion_tokens': 713, 'prompt_tokens': 13549, 'total_tokens': 14262}
#   Round: 10  Mean F1: 0.6191  Best: 0.6629  No-improve: 1  Tokens: {'completion_tokens': 710, 'prompt_tokens': 14771, 'total_tokens': 15481}
#   Round: 11  Mean F1: 0.6736  Best: 0.6736  No-improve: 0  Tokens: {'completion_tokens': 713, 'prompt_tokens': 15987, 'total_tokens': 16700}
#   Round: 12  Mean F1: 0.6761  Best: 0.6761  No-improve: 0  Tokens: {'completion_tokens': 713, 'prompt_tokens': 17208, 'total_tokens': 17921}
#   Train F1 history: [0.36054545235925994, 0.4776693687669698, 0.4757911528240717, 0.541550475359392, 0.5514459208041876, 0.6592746291608195, 0.6582680607262483, 0.6624341817684577, 0.6629324763669643, 0.6191149928054767, 0.6736404457264851, 0.6760907825699974]
#   Final best F1: 0.6761  (stopped after 12 rounds)
#
# === Target class: Mirai ===
#   Round: 1  Mean F1: 0.4421  Best: 0.4421  No-improve: 0  Tokens: {'completion_tokens': 811, 'prompt_tokens': 3500, 'total_tokens': 4311}
#   Round: 2  Mean F1: 0.4462  Best: 0.4462  No-improve: 0  Tokens: {'completion_tokens': 537, 'prompt_tokens': 4710, 'total_tokens': 5247}
#   Round: 3  Mean F1: 0.5331  Best: 0.5331  No-improve: 0  Tokens: {'completion_tokens': 535, 'prompt_tokens': 5650, 'total_tokens': 6185}
#   Round: 4  Mean F1: 0.5700  Best: 0.5700  No-improve: 0  Tokens: {'completion_tokens': 525, 'prompt_tokens': 6587, 'total_tokens': 7112}
#   Round: 5  Mean F1: 0.5227  Best: 0.5700  No-improve: 1  Tokens: {'completion_tokens': 525, 'prompt_tokens': 7514, 'total_tokens': 8039}
#   Round: 6  Mean F1: 0.6072  Best: 0.6072  No-improve: 0  Tokens: {'completion_tokens': 521, 'prompt_tokens': 8439, 'total_tokens': 8960}
#   Round: 7  Mean F1: 0.5967  Best: 0.6072  No-improve: 1  Tokens: {'completion_tokens': 521, 'prompt_tokens': 9357, 'total_tokens': 9878}
#   Round: 8  Mean F1: 0.5368  Best: 0.6072  No-improve: 2  Tokens: {'completion_tokens': 516, 'prompt_tokens': 10278, 'total_tokens': 10794}
#   Round: 9  Mean F1: 0.5716  Best: 0.6072  No-improve: 3  Tokens: {'completion_tokens': 522, 'prompt_tokens': 11189, 'total_tokens': 11711}
#   Round: 10  Mean F1: 0.5292  Best: 0.6072  No-improve: 4  Tokens: {'completion_tokens': 519, 'prompt_tokens': 12108, 'total_tokens': 12627}
#   Train F1 history: [0.4420689949181815, 0.4462135834880604, 0.5331451035486395, 0.5700478521663896, 0.5226781541046478, 0.6071713799856869, 0.5967149963517949, 0.5367900719515779, 0.5715887305612682, 0.5292470280415827]
#   Final best F1: 0.6072  (stopped after 10 rounds)
#
# === Target class: DDoS-Fragmentation ===
#   Round: 1  Mean F1: 0.3000  Best: 0.3000  No-improve: 0  Tokens: {'completion_tokens': 711, 'prompt_tokens': 3594, 'total_tokens': 4305}
#   Round: 2  Mean F1: 0.4480  Best: 0.4480  No-improve: 0  Tokens: {'completion_tokens': 549, 'prompt_tokens': 4707, 'total_tokens': 5256}
#   Round: 3  Mean F1: 0.3707  Best: 0.4480  No-improve: 1  Tokens: {'completion_tokens': 544, 'prompt_tokens': 5660, 'total_tokens': 6204}
#   Round: 4  Mean F1: 0.4326  Best: 0.4480  No-improve: 2  Tokens: {'completion_tokens': 545, 'prompt_tokens': 6608, 'total_tokens': 7153}
#   Round: 5  Mean F1: 0.5976  Best: 0.5976  No-improve: 0  Tokens: {'completion_tokens': 550, 'prompt_tokens': 7552, 'total_tokens': 8102}
#   Round: 6  Mean F1: 0.6608  Best: 0.6608  No-improve: 0  Tokens: {'completion_tokens': 538, 'prompt_tokens': 8500, 'total_tokens': 9038}
#   Round: 7  Mean F1: 0.6714  Best: 0.6714  No-improve: 0  Tokens: {'completion_tokens': 535, 'prompt_tokens': 9431, 'total_tokens': 9966}
#   Round: 8  Mean F1: 0.7799  Best: 0.7799  No-improve: 0  Tokens: {'completion_tokens': 538, 'prompt_tokens': 10361, 'total_tokens': 10899}
#   Round: 9  Mean F1: 0.8031  Best: 0.8031  No-improve: 0  Tokens: {'completion_tokens': 533, 'prompt_tokens': 11289, 'total_tokens': 11822}
#   Round: 10  Mean F1: 0.8051  Best: 0.8051  No-improve: 0  Tokens: {'completion_tokens': 532, 'prompt_tokens': 12213, 'total_tokens': 12745}
#   Round: 11  Mean F1: 0.8364  Best: 0.8364  No-improve: 0  Tokens: {'completion_tokens': 537, 'prompt_tokens': 13136, 'total_tokens': 13673}
#   Round: 12  Mean F1: 0.8245  Best: 0.8364  No-improve: 1  Tokens: {'completion_tokens': 535, 'prompt_tokens': 14067, 'total_tokens': 14602}
#   Round: 13  Mean F1: 0.8353  Best: 0.8364  No-improve: 2  Tokens: {'completion_tokens': 539, 'prompt_tokens': 14995, 'total_tokens': 15534}
#   Round: 14  Mean F1: 0.8353  Best: 0.8364  No-improve: 3  Tokens: {'completion_tokens': 537, 'prompt_tokens': 15928, 'total_tokens': 16465}
#   Round: 15  Mean F1: 0.8020  Best: 0.8364  No-improve: 4  Tokens: {'completion_tokens': 537, 'prompt_tokens': 16862, 'total_tokens': 17399}
#   Train F1 history: [0.3000044595121981, 0.4480249267044633, 0.37073181232615493, 0.4326416803000689, 0.5976490373901597, 0.6608449714990695, 0.6714253388031345, 0.7798553803197668, 0.8031360521709207, 0.805115376195815, 0.8363818570530974, 0.8244993749037175, 0.8353267240081191, 0.8352832784595314, 0.8019921276453683]
#   Final best F1: 0.8364  (stopped after 15 rounds)
#
# === Target class: Recon ===
#   Round: 1  Mean F1: 0.2391  Best: 0.2391  No-improve: 0  Tokens: {'completion_tokens': 926, 'prompt_tokens': 3583, 'total_tokens': 4509}
#   Round: 2  Mean F1: 0.3145  Best: 0.3145  No-improve: 0  Tokens: {'completion_tokens': 718, 'prompt_tokens': 5023, 'total_tokens': 5741}
#   Round: 3  Mean F1: 0.4700  Best: 0.4700  No-improve: 0  Tokens: {'completion_tokens': 713, 'prompt_tokens': 6255, 'total_tokens': 6968}
#   Round: 4  Mean F1: 0.4398  Best: 0.4700  No-improve: 1  Tokens: {'completion_tokens': 713, 'prompt_tokens': 7485, 'total_tokens': 8198}
#   Round: 5  Mean F1: 0.3771  Best: 0.4700  No-improve: 2  Tokens: {'completion_tokens': 709, 'prompt_tokens': 8715, 'total_tokens': 9424}
#   Round: 6  Mean F1: 0.3621  Best: 0.4700  No-improve: 3  Tokens: {'completion_tokens': 706, 'prompt_tokens': 9937, 'total_tokens': 10643}
#   Round: 7  Mean F1: 0.4372  Best: 0.4700  No-improve: 4  Tokens: {'completion_tokens': 709, 'prompt_tokens': 11153, 'total_tokens': 11862}
#   Train F1 history: [0.23906501651770726, 0.31446225232344205, 0.469987964051982, 0.43975425322732875, 0.37712101590797875, 0.3620783312160922, 0.4372354534913698]
#   Final best F1: 0.4700  (stopped after 7 rounds)
#
# === Target class: MITM-ArpSpoofing ===
#   Round: 1  Mean F1: 0.4102  Best: 0.4102  No-improve: 0  Tokens: {'completion_tokens': 988, 'prompt_tokens': 3611, 'total_tokens': 4599}
#   Round: 2  Mean F1: 0.4343  Best: 0.4343  No-improve: 0  Tokens: {'completion_tokens': 765, 'prompt_tokens': 5119, 'total_tokens': 5884}
#   Round: 3  Mean F1: 0.4330  Best: 0.4343  No-improve: 1  Tokens: {'completion_tokens': 746, 'prompt_tokens': 6399, 'total_tokens': 7145}
#   Round: 4  Mean F1: 0.4654  Best: 0.4654  No-improve: 0  Tokens: {'completion_tokens': 746, 'prompt_tokens': 7661, 'total_tokens': 8407}
#   Round: 5  Mean F1: 0.4576  Best: 0.4654  No-improve: 1  Tokens: {'completion_tokens': 756, 'prompt_tokens': 8925, 'total_tokens': 9681}
#   Round: 6  Mean F1: 0.4886  Best: 0.4886  No-improve: 0  Tokens: {'completion_tokens': 743, 'prompt_tokens': 10193, 'total_tokens': 10936}
#   Round: 7  Mean F1: 0.4975  Best: 0.4975  No-improve: 0  Tokens: {'completion_tokens': 746, 'prompt_tokens': 11448, 'total_tokens': 12194}
#   Round: 8  Mean F1: 0.4183  Best: 0.4975  No-improve: 1  Tokens: {'completion_tokens': 748, 'prompt_tokens': 12708, 'total_tokens': 13456}
#   Round: 9  Mean F1: 0.4541  Best: 0.4975  No-improve: 2  Tokens: {'completion_tokens': 748, 'prompt_tokens': 13973, 'total_tokens': 14721}
#   Round: 10  Mean F1: 0.4862  Best: 0.4975  No-improve: 3  Tokens: {'completion_tokens': 749, 'prompt_tokens': 15237, 'total_tokens': 15986}
#   Round: 11  Mean F1: 0.4781  Best: 0.4975  No-improve: 4  Tokens: {'completion_tokens': 750, 'prompt_tokens': 16502, 'total_tokens': 17252}
#   Train F1 history: [0.41022947188502845, 0.43425981171899114, 0.4330495196730788, 0.4654055183367083, 0.45763012977386736, 0.48859357458633823, 0.49748675527106095, 0.418294003498569, 0.4541000374164284, 0.48621524942471356, 0.4781319145620376]
#   Final best F1: 0.4975  (stopped after 11 rounds)
#
# === Target class: DNS_Spoofing ===
#   Round: 1  Mean F1: 0.2755  Best: 0.2755  No-improve: 0  Tokens: {'completion_tokens': 910, 'prompt_tokens': 3604, 'total_tokens': 4514}
#   Round: 2  Mean F1: 0.3742  Best: 0.3742  No-improve: 0  Tokens: {'completion_tokens': 727, 'prompt_tokens': 5027, 'total_tokens': 5754}
#   Round: 3  Mean F1: 0.4022  Best: 0.4022  No-improve: 0  Tokens: {'completion_tokens': 719, 'prompt_tokens': 6267, 'total_tokens': 6986}
#   Round: 4  Mean F1: 0.4053  Best: 0.4053  No-improve: 0  Tokens: {'completion_tokens': 716, 'prompt_tokens': 7501, 'total_tokens': 8217}
#   Round: 5  Mean F1: 0.4262  Best: 0.4262  No-improve: 0  Tokens: {'completion_tokens': 717, 'prompt_tokens': 8731, 'total_tokens': 9448}
#   Round: 6  Mean F1: 0.4341  Best: 0.4341  No-improve: 0  Tokens: {'completion_tokens': 717, 'prompt_tokens': 9962, 'total_tokens': 10679}
#   Round: 7  Mean F1: 0.2842  Best: 0.4341  No-improve: 1  Tokens: {'completion_tokens': 722, 'prompt_tokens': 11195, 'total_tokens': 11917}
#   Round: 8  Mean F1: 0.3730  Best: 0.4341  No-improve: 2  Tokens: {'completion_tokens': 719, 'prompt_tokens': 12435, 'total_tokens': 13154}
#   Round: 9  Mean F1: 0.3890  Best: 0.4341  No-improve: 3  Tokens: {'completion_tokens': 719, 'prompt_tokens': 13669, 'total_tokens': 14388}
#   Round: 10  Mean F1: 0.4001  Best: 0.4341  No-improve: 4  Tokens: {'completion_tokens': 720, 'prompt_tokens': 14903, 'total_tokens': 15623}
#   Train F1 history: [0.2755185646521924, 0.3741626865450897, 0.40216139730447775, 0.4052981888220378, 0.42621853579500074, 0.43409110323341454, 0.284157533109969, 0.37296314502885836, 0.38897011719642866, 0.40012173866653356]
#   Final best F1: 0.4341  (stopped after 10 rounds)
#
# Done. Classes with rules: ['DDoS-Flood', 'DoS-Flood', 'Mirai', 'DDoS-Fragmentation', 'Recon', 'MITM-ArpSpoofing', 'DNS_Spoofing']
# Saved class rules to: results/llm/class_rules-multiclass-100000.json

# %%
import json

with open("results/llm/class_rules-multiclass-100000.json") as f:
    rules = json.load(f)
print(json.dumps(rules['DDoS-Flood'], indent=2))
# Out:
# [
#   {
#     "args": {
#       "feature_name": "AVG",
#       "op": "<=",
#       "value": "60.0",
#       "target_class": "DDoS-Flood"
#     }
#   },
#   {
#     "args": {
#       "feature_name": "Radius",
#       "op": "<",
#       "value": "0.1",
#       "target_class": "DDoS-Flood"
#     }
#   },
#   {
#     "args": {
#       "feature_name": "Std",
#       "op": "<",
#       "value": "0.1",
#       "target_class": "DDoS-Flood"
#     }
#   },
#   {
#     "args": {
#       "feature_name": "Tot sum",
#       "op": "<",
#       "value": "600.0",
#       "target_class": "DDoS-Flood"
#     }
#   },
#   {
#     "args": {
#       "feature_name": "Max",
#       "op": "<=",
#       "value": "60.0",
#       "target_class": "DDoS-Flood"
#     }
#   }
# ]

# %% [markdown]
# # Evaluate All Rules on Test Set (Multi-Class)

# %%
# Check 1: do the feature names actually exist in X_test?
for tc in rules['DDoS-Flood']:
    feat = tc['args']['feature_name']
    print(f"'{feat}' in X_test.columns: {feat in X_test.columns}")
# Out:
# 'AVG' in X_test.columns: True
# 'Radius' in X_test.columns: True
# 'Std' in X_test.columns: True
# 'Tot sum' in X_test.columns: True
# 'Max' in X_test.columns: True

# %%
for i, (_, row) in enumerate(ddos_test_rows.iterrows()):
    scores = {}
    for cls, tool_calls in class_rules.items():
        if len(tool_calls) == 0:
            scores[cls] = 0.0
            continue
        count = sum(
            1 for tc in tool_calls
            if tc['args']['op'] in operations
            and tc['args']['feature_name'] in row.index
            and operations[tc['args']['op']](
                row[tc['args']['feature_name']],
                float(tc['args']['value'])
            )
        )
        scores[cls] = count / len(tool_calls)
    print(f"Row {i}: {scores} → predicted: {max(scores, key=scores.get)}")
# Out:
# Row 0: {'DDoS-Flood': 0.6, 'DoS-Flood': 1.0, 'Mirai': 0.4, 'DDoS-Fragmentation': 0.0, 'Recon': 0.2857142857142857, 'MITM-ArpSpoofing': 0.0, 'DNS_Spoofing': 0.2857142857142857} → predicted: DoS-Flood
# Row 1: {'DDoS-Flood': 1.0, 'DoS-Flood': 1.0, 'Mirai': 0.6, 'DDoS-Fragmentation': 0.0, 'Recon': 0.2857142857142857, 'MITM-ArpSpoofing': 0.0, 'DNS_Spoofing': 0.2857142857142857} → predicted: DDoS-Flood
# Row 2: {'DDoS-Flood': 1.0, 'DoS-Flood': 0.7142857142857143, 'Mirai': 0.6, 'DDoS-Fragmentation': 0.0, 'Recon': 0.14285714285714285, 'MITM-ArpSpoofing': 0.0, 'DNS_Spoofing': 0.0} → predicted: DDoS-Flood
# Row 3: {'DDoS-Flood': 1.0, 'DoS-Flood': 1.0, 'Mirai': 0.4, 'DDoS-Fragmentation': 0.0, 'Recon': 0.2857142857142857, 'MITM-ArpSpoofing': 0.0, 'DNS_Spoofing': 0.2857142857142857} → predicted: DDoS-Flood
# Row 4: {'DDoS-Flood': 1.0, 'DoS-Flood': 0.7142857142857143, 'Mirai': 0.6, 'DDoS-Fragmentation': 0.0, 'Recon': 0.14285714285714285, 'MITM-ArpSpoofing': 0.2857142857142857, 'DNS_Spoofing': 0.14285714285714285} → predicted: DDoS-Flood
# Row 5: {'DDoS-Flood': 1.0, 'DoS-Flood': 0.7142857142857143, 'Mirai': 0.6, 'DDoS-Fragmentation': 0.0, 'Recon': 0.14285714285714285, 'MITM-ArpSpoofing': 0.2857142857142857, 'DNS_Spoofing': 0.0} → predicted: DDoS-Flood
# Row 6: {'DDoS-Flood': 1.0, 'DoS-Flood': 0.7142857142857143, 'Mirai': 1.0, 'DDoS-Fragmentation': 0.0, 'Recon': 0.14285714285714285, 'MITM-ArpSpoofing': 0.0, 'DNS_Spoofing': 0.2857142857142857} → predicted: DDoS-Flood
# Row 7: {'DDoS-Flood': 1.0, 'DoS-Flood': 0.7142857142857143, 'Mirai': 0.6, 'DDoS-Fragmentation': 0.0, 'Recon': 0.2857142857142857, 'MITM-ArpSpoofing': 0.0, 'DNS_Spoofing': 0.2857142857142857} → predicted: DDoS-Flood
# Row 8: {'DDoS-Flood': 0.6, 'DoS-Flood': 1.0, 'Mirai': 1.0, 'DDoS-Fragmentation': 0.0, 'Recon': 0.14285714285714285, 'MITM-ArpSpoofing': 0.0, 'DNS_Spoofing': 0.2857142857142857} → predicted: DoS-Flood
# Row 9: {'DDoS-Flood': 1.0, 'DoS-Flood': 0.7142857142857143, 'Mirai': 1.0, 'DDoS-Fragmentation': 0.0, 'Recon': 0.14285714285714285, 'MITM-ArpSpoofing': 0.2857142857142857, 'DNS_Spoofing': 0.0} → predicted: DDoS-Flood

# %%
################################################################################
# Evaluate generated rules on test set (multi-class)
# Load learned rules from disk instead of in-memory state
################################################################################

import json
import operator
import os
from sklearn.metrics import classification_report, confusion_matrix
from tqdm import tqdm

operations = {'<': operator.lt, '>': operator.gt, '==': operator.eq,
              '<=': operator.le, '>=': operator.ge, '!=': operator.ne}

os.makedirs("results/llm", exist_ok=True)
rules_input_path = "results/llm/class_rules-multiclass-100000.json"

with open(rules_input_path, "r") as f:
    class_rules = json.load(f)

# Sanity check before running 2666 predictions
assert len(class_rules) == 7, f"Expected 7 classes, got {len(class_rules)}"
for cls, rules in class_rules.items():
    assert len(rules) > 0, f"Class {cls} has no rules"
print(f"Loaded {len(class_rules)} classes, rule counts: { {c: len(r) for c, r in class_rules.items()} }")

def predict_multiclass(row, class_rules):
    scores = {}
    for cls, tool_calls in class_rules.items():
        if len(tool_calls) == 0:
            scores[cls] = 0.0
            continue
        count = 0
        for tc in tool_calls:
            args = tc["args"]
            op, feat, val = args["op"], args["feature_name"], args["value"]
            try:
                val = float(val)
            except ValueError:
                pass
            if op in operations and feat in row.index:
                if operations[op](row[feat], val):
                    count += 1
        # Normalise: proportion of rules that fired, not raw count
        scores[cls] = count / len(tool_calls)

    max_score = max(scores.values()) if scores else 0.0
    if max_score == 0.0:
        return 'BenignTraffic'

    winners = [cls for cls, s in scores.items() if s == max_score]
    return winners[0] if len(winners) == 1 else 'BenignTraffic'

y_pred_llm, y_true_llm = [], []
for i in tqdm(range(len(X_test)), desc="Evaluating multiclass rules"):
    row = X_test.iloc[i]
    y_true_llm.append(y_test.iloc[i])
    y_pred_llm.append(predict_multiclass(row, class_rules))

report = classification_report(y_true_llm, y_pred_llm, digits=4)
matrix = confusion_matrix(y_true_llm, y_pred_llm)
print(report)
with open("results/llm/result-llm-multiclass-100000.txt", "w") as f:
    f.write(f"Classification Report\n{report}\n\nConfusion Matrix\n{matrix}\n")
# Out:
# Loaded 7 classes, rule counts: {'DDoS-Flood': 5, 'DoS-Flood': 7, 'Mirai': 5, 'DDoS-Fragmentation': 5, 'Recon': 7, 'MITM-ArpSpoofing': 7, 'DNS_Spoofing': 7}
# Evaluating multiclass rules: 100%|██████████| 2666/2666 [00:00<00:00, 15478.76it/s]
#                     precision    recall  f1-score   support
#
#      BenignTraffic     0.2865    0.3426    0.3120       470
#         DDoS-Flood     0.5163    0.4383    0.4741       470
# DDoS-Fragmentation     0.7482    0.9400    0.8332       433
#       DNS_Spoofing     0.1065    0.2222    0.1440        81
#          DoS-Flood     0.6370    0.1979    0.3019       470
#   MITM-ArpSpoofing     0.3540    0.3053    0.3279       131
#              Mirai     0.8068    0.9064    0.8537       470
#              Recon     0.3024    0.4397    0.3584       141
#
#           accuracy                         0.5300      2666
#          macro avg     0.4697    0.4740    0.4506      2666
#       weighted avg     0.5542    0.5300    0.5171      2666

# %% [markdown]
# # Efficiency Comparison

# %%
################################################################################
# Efficiency Comparison
################################################################################

import time
from tabulate import tabulate
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# Retrain DT and RF for timing
model_dt = DecisionTreeClassifier(random_state=42)
model_rf = RandomForestClassifier(random_state=42)
model_dt.fit(X_train, y_train)
model_rf.fit(X_train, y_train)

elapsed_dt, elapsed_rf, elapsed_llm = [], [], []
n_samples = min(1000, len(X_test))   # cap to avoid slow LLM rules

for i in range(n_samples):
    row = X_test.iloc[[i]]

    t0 = time.time()
    model_dt.predict(row)
    elapsed_dt.append(time.time() - t0)
    
    t0 = time.time()
    model_rf.predict(row)
    elapsed_rf.append(time.time() - t0)
    
    t0 = time.time()
    # predict_multiclass(X_test.iloc[i], class_rules)
    elapsed_llm.append(time.time() - t0)

rows = [
    ["Decision Tree", f"{sum(elapsed_dt)/n_samples*1e3:.4f} ms"],
    ["Random Forest", f"{sum(elapsed_rf)/n_samples*1e3:.4f} ms"],
    ["LLM Rules",     f"{sum(elapsed_llm)/n_samples*1e3:.4f} ms"],
]
print(tabulate(rows, headers=["Model", "Avg Inference Time"], tablefmt="grid"))
# Out:
# +---------------+----------------------+
# | Model         | Avg Inference Time   |
# +===============+======================+
# | Decision Tree | 0.2752 ms            |
# +---------------+----------------------+
# | Random Forest | 2.0495 ms            |
# +---------------+----------------------+
# | LLM Rules     | 0.0001 ms            |
# +---------------+----------------------+

# %% [markdown]
# # Binary Evaluation (Attack vs Benign)

# %%
################################################################################
# Binary Evaluation — Attack vs Benign (collapsed from multiclass)
# Compares DT, RF, and LLM rules on the same test set
################################################################################

import json
import operator
import os
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
from tabulate import tabulate

operations = {'<': operator.lt, '>': operator.gt, '==': operator.eq,
              '<=': operator.le, '>=': operator.ge, '!=': operator.ne}

def to_binary(labels):
    """Collapse any non-BenignTraffic label → 'attack', BenignTraffic → 'normal'."""
    return ['normal' if l == 'BenignTraffic' else 'attack' for l in labels]

def predict_multiclass(row, class_rules):
    scores = {}
    for cls, tool_calls in class_rules.items():
        if len(tool_calls) == 0:
            scores[cls] = 0.0
            continue
        count = 0
        for tc in tool_calls:
            args = tc["args"]
            op, feat, val = args["op"], args["feature_name"], args["value"]
            try:
                val = float(val)
            except ValueError:
                pass
            if op in operations and feat in row.index and operations[op](row[feat], val):
                count += 1
        scores[cls] = count / len(tool_calls)

    max_score = max(scores.values()) if scores else 0.0
    if max_score == 0.0:
        return 'BenignTraffic'

    winners = [cls for cls, s in scores.items() if s == max_score]
    return winners[0] if len(winners) == 1 else 'BenignTraffic'

rules_input_path = "results/llm/class_rules-multiclass-100000.json"
with open(rules_input_path, "r") as f:
    class_rules = json.load(f)

# Re-train DT and RF so this cell does not depend on earlier model variables.
model_dt = DecisionTreeClassifier(random_state=42)
model_rf = RandomForestClassifier(random_state=42)
model_dt.fit(X_train, y_train)
model_rf.fit(X_train, y_train)

# Re-predict with DT, RF, and saved LLM rules.
y_pred_dt = model_dt.predict(X_test)
y_pred_rf = model_rf.predict(X_test)
y_pred_llm = [predict_multiclass(X_test.iloc[i], class_rules) for i in range(len(X_test))]

# Ground truth in binary
y_true_bin = to_binary(y_test.tolist())

# Model predictions in binary
y_pred_dt_bin  = to_binary(y_pred_dt.tolist())
y_pred_rf_bin  = to_binary(y_pred_rf.tolist())
y_pred_llm_bin = to_binary(y_pred_llm)

print("=== Binary Classification: Attack vs Benign ===\n")
for name, y_pred_bin in [("Decision Tree", y_pred_dt_bin),
                          ("Random Forest", y_pred_rf_bin),
                          ("LLM Rules",     y_pred_llm_bin)]:
    report = classification_report(y_true_bin, y_pred_bin, digits=4, output_dict=True)
    matrix = confusion_matrix(y_true_bin, y_pred_bin, labels=["normal", "attack"])
    print(f"--- {name} ---")
    print(classification_report(y_true_bin, y_pred_bin, digits=4))
    print(f"Confusion matrix (rows=true, cols=pred, order=[normal, attack]):")
    print(matrix, "\n")

# Summary comparison table
summary = []
for name, y_pred_bin in [("Decision Tree", y_pred_dt_bin),
                          ("Random Forest", y_pred_rf_bin),
                          ("LLM Rules",     y_pred_llm_bin)]:
    r = classification_report(y_true_bin, y_pred_bin, digits=4, output_dict=True)
    summary.append([
        name,
        f"{r['normal']['precision']:.4f}",
        f"{r['normal']['recall']:.4f}",
        f"{r['normal']['f1-score']:.4f}",
        f"{r['attack']['precision']:.4f}",
        f"{r['attack']['recall']:.4f}",
        f"{r['attack']['f1-score']:.4f}",
        f"{r['macro avg']['f1-score']:.4f}",
        f"{r['accuracy']:.4f}",
    ])

headers = ["Model",
           "Normal-P", "Normal-R", "Normal-F1",
           "Attack-P",  "Attack-R",  "Attack-F1",
           "Macro-F1",  "Accuracy"]
print(tabulate(summary, headers=headers, tablefmt="grid"))

# Save to file
with open("results/llm/result-llm-multiclass-binary-100000.txt", "w") as f:
    f.write("Binary (Attack vs Benign) Evaluation — derived from multiclass predictions\n\n")
    f.write(tabulate(summary, headers=headers, tablefmt="grid"))
    f.write("\n")
print("\nSaved to results/llm/result-llm-multiclass-binary-100000.txt")
# Out:
# === Binary Classification: Attack vs Benign ===
#
# --- Decision Tree ---
#               precision    recall  f1-score   support
#
#       attack     0.9756    0.9827    0.9791      2196
#       normal     0.9163    0.8851    0.9004       470
#
#     accuracy                         0.9655      2666
#    macro avg     0.9459    0.9339    0.9398      2666
# weighted avg     0.9651    0.9655    0.9653      2666
#
# Confusion matrix (rows=true, cols=pred, order=[normal, attack]):
# [[ 416   54]
#  [  38 2158]]
#
# --- Random Forest ---
#               precision    recall  f1-score   support
#
#       attack     0.9916    0.9658    0.9785      2196
#       normal     0.8577    0.9617    0.9067       470
#
#     accuracy                         0.9651      2666
#    macro avg     0.9246    0.9638    0.9426      2666
# weighted avg     0.9680    0.9651    0.9659      2666
#
# Confusion matrix (rows=true, cols=pred, order=[normal, attack]):
# [[ 452   18]
#  [  75 2121]]
#
# --- LLM Rules ---
#               precision    recall  f1-score   support
#
#       attack     0.8531    0.8174    0.8349      2196
#       normal     0.2865    0.3426    0.3120       470
#
#     accuracy                         0.7337      2666
#    macro avg     0.5698    0.5800    0.5734      2666
# weighted avg     0.7532    0.7337    0.7427      2666
#
# Confusion matrix (rows=true, cols=pred, order=[normal, attack]):
# [[ 161  309]
#  [ 401 1795]]
#
# +---------------+------------+------------+-------------+------------+------------+-------------+------------+------------+
# | Model         |   Normal-P |   Normal-R |   Normal-F1 |   Attack-P |   Attack-R |   Attack-F1 |   Macro-F1 |   Accuracy |
# +===============+============+============+=============+============+============+=============+============+============+
# | Decision Tree |     0.9163 |     0.8851 |      0.9004 |     0.9756 |     0.9827 |      0.9791 |     0.9398 |     0.9655 |
# +---------------+------------+------------+-------------+------------+------------+-------------+------------+------------+
# | Random Forest |     0.8577 |     0.9617 |      0.9067 |     0.9916 |     0.9658 |      0.9785 |     0.9426 |     0.9651 |
# +---------------+------------+------------+-------------+------------+------------+-------------+------------+------------+
# | LLM Rules     |     0.2865 |     0.3426 |      0.312  |     0.8531 |     0.8174 |      0.8349 |     0.5734 |     0.7337 |
# +---------------+------------+------------+-------------+------------+------------+-------------+------------+------------+
#
# Saved to results/llm/result-llm-multiclass-binary-100000.txt
